# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
from scipy.io import loadmat
datas = loadmat("/content/gdrive/My Drive/pattern/pattern2019/CD_PD.mat", squeeze_me=True)
#squeeze_me remove redundant dimensions

# %%
datas['dat'].size #dat is upmost level, which is an array of size 1.
#There are 196 subjects in this dataset.
# Out:
# 196

# %%
datas['dat'][0]['age'] #let's get the age of the first subject
# Out:
# 45

# %%
datas['dat'][1]['age'] #let's get the age of the second subject
# Out:
# 64

# %%
datas['dat']['age'] #note there are missing ages!
# Out:
# array([45, 64, 50, 67, 64, 50, 49, 77, 60, 78, 56, 78, 0, 0, 0, 0, 53, 59,
#        63, 56, 52, 55, 0, 55, 61, 64, 51, 62, 42, 59, 71, 67, 65, 56, 56,
#        57, 57, 48, 44, 65, 69, 67, 58, 60, 66, 58, 53, 52, 43, 53, 52, 63,
#        73, 54, 56, 56, 73, 48, 69, 73, 63, 63, 64, 64, 58, 65, 65, 0, 45,
#        45, 67, 64, 64, 49, 49, 39, 39, 55, 55, 60, 60, 64, 64, 48, 35, 35,
#        58, 63, 62, 73, 76, 76, 63, 63, 57, 57, 68, 68, 0, 65, 57, 57, 40,
#        40, 79, 79, 42, 60, 53, 62, 66, 70, 61, 44, 62, 62, 53, 53, 68, 65,
#        47, 47, 59, 59, 53, 51, 51, 63, 63, 47, 47, 79, 79, 58, 40, 0, 0,
#        64, 67, 81, 81, 48, 77, 63, 60, 58, 58, 49, 64, 68, 63, 76, 43, 43,
#        66, 59, 71, 74, 63, 54, 60, 42, 55, 65, 54, 69, 61, 43, 0, 0, 49,
#        74, 54, 66, 72, 69, 54, 52, 59, 85, 85, 64, 75, 61, 72, 61, 49, 70,
#        69, 65, 51, 0, 64, 69, 51, 46], dtype=object)

# %% [markdown]
# Below is all the data per subject
#
#
# 1.   age
# 2.   date
# 3.   duration
# 4.   ed
# 5.    gender
# 6.    side
# 7.    TMSE
# 8.    t
# 9.    x
# 10.    y
# 11.    p
# 12.    pt
# 13.    diagnosis
# 14.    clock_drawing

# %%
datas['dat']['TMSE']
# Out:
# array([0, 30, 28, 30, 26, 30, 30, 30, 28, 29, 27, 0, 0, 0, 0, 26, 27, 29,
#        29, 29, 28, 0, 28, 29, 30, 27, 29, 26, 29, 28, 29, 29, 30, 30, 30,
#        25, 25, 30, 29, 30, 28, 26, 30, 28, 26, 29, 27, 27, 29, 28, 30, 28,
#        29, 27, 30, 30, 30, 24, 29, 28, 30, 30, 27, 27, 29, 29, 29, 27, 29,
#        29, 27, 28, 28, 27, 27, 29, 29, 27, 27, 28, 28, 30, 30, 30, 30, 30,
#        29, 29, 29, 28, 28, 29, 28, 28, 0, 28, 29, 29, 29, 29, 27, 27, 28,
#        28, 27, 27, 29, 26, 29, 26, 30, 27, 26, 29, 30, 30, 30, 30, 30, 30,
#        25, 25, 29, 29, 29, 30, 30, 27, 27, 30, 30, 26, 26, 26, 29, 0, 0,
#        27, 28, 0, 0, 29, 27, 28, 26, 25, 25, 29, 27, 28, 25, 28, 29, 28,
#        25, 24, 29, 25, 30, 26, 29, 30, 27, 30, 27, 28, 28, 29, 0, 0, 29,
#        26, 29, 29, 27, 27, 29, 28, 27, 0, 0, 27, 24, 29, 28, 27, 26, 24,
#        27, 30, 28, 0, 26, 29, 27, 25], dtype=object)

# %%
datas['dat'][0]['t'] #time stamps from drawing of first subject
# Out:
# array([0.00000000e+00, 9.26665962e-08, 1.15716830e-07, 8.57643317e-06,
#        8.80786683e-06, 8.99308361e-06, 9.17830039e-06, 9.37504228e-06,
#        9.57178418e-06, 9.76852607e-06, 9.95374285e-06, 1.01504847e-05,
#        1.02893682e-05, 1.03008933e-05, 1.55208400e-05, 1.57523900e-05,
#        1.59491319e-05, 1.61342323e-05, 1.63310906e-05, 1.65278325e-05,
#        1.67245744e-05, 1.69097912e-05, 1.71065331e-05, 1.73032749e-05,
#        1.74884917e-05, 1.76852336e-05, 1.78819755e-05, 1.80787174e-05,
#        1.82754593e-05, 1.84606761e-05, 1.86574180e-05, 1.88426347e-05,
#        1.90393766e-05, 1.92361185e-05, 1.94213353e-05, 1.96180772e-05,
#        1.98148191e-05, 2.00115610e-05, 2.02083029e-05, 2.03935197e-05,
#        2.05902616e-05, 2.07291450e-05, 2.07407866e-05, 3.89815541e-05,
#        3.91434878e-05, 3.93403461e-05, 3.95370880e-05, 3.97338299e-05,
#        3.99190467e-05, 4.01157886e-05, 4.03125305e-05, 4.04977472e-05,
# ...
